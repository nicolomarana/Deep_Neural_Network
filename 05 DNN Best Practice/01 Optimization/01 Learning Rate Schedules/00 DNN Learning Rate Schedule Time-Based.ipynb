# %%
# Time Based Learning Rate Decay
from pandas import read_csv
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
from sklearn.preprocessing import LabelEncoder
# Out:
# Using TensorFlow backend.

# %%
# load dataset
filename='https://gist.githubusercontent.com/nicolomarana/cd4fb1594124f42337157eec1d8cfa64/raw/e9c0b0fba99bb232250d1ecbcd80d1c1f31f50cf/ionosphere'
dataframe = read_csv(filename, header=None)
dataset = dataframe.values

# %%
# split into input (X) and output (Y) variables
X = dataset[:,0:34].astype(float)
Y = dataset[:,34]

# %%
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(Y)
Y = encoder.transform(Y)

# %%
# create model
model = Sequential()
model.add(Dense(34, input_dim=34, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile model
epochs = 50
learning_rate = 0.1
decay_rate = learning_rate / epochs
momentum = 0.8
sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=epochs, batch_size=28, verbose=2)
# Out:
# Train on 235 samples, validate on 116 samples
# Epoch 1/50
#  - 0s - loss: 0.6299 - accuracy: 0.6638 - val_loss: 0.5183 - val_accuracy: 0.7155
# Epoch 2/50
#  - 0s - loss: 0.4683 - accuracy: 0.8255 - val_loss: 0.4189 - val_accuracy: 0.9569
# Epoch 3/50
#  - 0s - loss: 0.3498 - accuracy: 0.8894 - val_loss: 0.2366 - val_accuracy: 0.9655
# Epoch 4/50
#  - 0s - loss: 0.3006 - accuracy: 0.9021 - val_loss: 0.2490 - val_accuracy: 0.9741
# Epoch 5/50
#  - 0s - loss: 0.2342 - accuracy: 0.9191 - val_loss: 0.2302 - val_accuracy: 0.9741
# Epoch 6/50
#  - 0s - loss: 0.2012 - accuracy: 0.9447 - val_loss: 0.1354 - val_accuracy: 0.9741
# Epoch 7/50
#  - 0s - loss: 0.2030 - accuracy: 0.9362 - val_loss: 0.1791 - val_accuracy: 0.9741
# Epoch 8/50
#  - 0s - loss: 0.1628 - accuracy: 0.9447 - val_loss: 0.1178 - val_accuracy: 0.9828
# Epoch 9/50
#  - 0s - loss: 0.1670 - accuracy: 0.9404 - val_loss: 0.1310 - val_accuracy: 0.9828
# Epoch 10/50
#  - 0s - loss: 0.1494 - accuracy: 0.9489 - val_loss: 0.1475 - val_accuracy: 0.9828
# Epoch 11/50
#  - 0s - loss: 0.1353 - accuracy: 0.9574 - val_loss: 0.1390 - val_accuracy: 0.9828
# Epoch 12/50
#  - 0s - loss: 0.1213 - accuracy: 0.9702 - val_loss: 0.0908 - val_accuracy: 0.9828
# Epoch 13/50
#  - 0s - loss: 0.1261 - accuracy: 0.9574 - val_loss: 0.1185 - val_accuracy: 0.9828
# Epoch 14/50
#  - 0s - loss: 0.1157 - accuracy: 0.9617 - val_loss: 0.1096 - val_accuracy: 0.9828
# Epoch 15/50
#  - 0s - loss: 0.1069 - accuracy: 0.9702 - val_loss: 0.0832 - val_accuracy: 0.9828
# Epoch 16/50
#  - 0s - loss: 0.1016 - accuracy: 0.9745 - val_loss: 0.1270 - val_accuracy: 0.9741
# Epoch 17/50
#  - 0s - loss: 0.0992 - accuracy: 0.9787 - val_loss: 0.0920 - val_accuracy: 0.9828
# Epoch 18/50
#  - 0s - loss: 0.0906 - accuracy: 0.9830 - val_loss: 0.1042 - val_accuracy: 0.9828
# Epoch 19/50
#  - 0s - loss: 0.0869 - accuracy: 0.9830 - val_loss: 0.0827 - val_accuracy: 0.9828
# Epoch 20/50
#  - 0s - loss: 0.0864 - accuracy: 0.9787 - val_loss: 0.0905 - val_accuracy: 0.9828
# Epoch 21/50
#  - 0s - loss: 0.0826 - accuracy: 0.9830 - val_loss: 0.0807 - val_accuracy: 0.9828
# Epoch 22/50
#  - 0s - loss: 0.0800 - accuracy: 0.9830 - val_loss: 0.1066 - val_accuracy: 0.9741
# Epoch 23/50
#  - 0s - loss: 0.0779 - accuracy: 0.9830 - val_loss: 0.0679 - val_accuracy: 0.9828
# Epoch 24/50
#  - 0s - loss: 0.0800 - accuracy: 0.9660 - val_loss: 0.1288 - val_accuracy: 0.9655
# Epoch 25/50
#  - 0s - loss: 0.0782 - accuracy: 0.9702 - val_loss: 0.0600 - val_accuracy: 0.9828
# Epoch 26/50
#  - 0s - loss: 0.0803 - accuracy: 0.9745 - val_loss: 0.1403 - val_accuracy: 0.9569
# Epoch 27/50
#  - 0s - loss: 0.0805 - accuracy: 0.9787 - val_loss: 0.0719 - val_accuracy: 0.9828
# Epoch 28/50
#  - 0s - loss: 0.0686 - accuracy: 0.9830 - val_loss: 0.0799 - val_accuracy: 0.9741
# Epoch 29/50
#  - 0s - loss: 0.0655 - accuracy: 0.9830 - val_loss: 0.0748 - val_accuracy: 0.9828
# Epoch 30/50
#  - 0s - loss: 0.0636 - accuracy: 0.9830 - val_loss: 0.0763 - val_accuracy: 0.9741
# Epoch 31/50
#  - 0s - loss: 0.0627 - accuracy: 0.9830 - val_loss: 0.0660 - val_accuracy: 0.9828
# Epoch 32/50
#  - 0s - loss: 0.0625 - accuracy: 0.9830 - val_loss: 0.0693 - val_accuracy: 0.9828
# Epoch 33/50
#  - 0s - loss: 0.0605 - accuracy: 0.9830 - val_loss: 0.0673 - val_accuracy: 0.9828
# Epoch 34/50
#  - 0s - loss: 0.0600 - accuracy: 0.9830 - val_loss: 0.0689 - val_accuracy: 0.9741
# Epoch 35/50
#  - 0s - loss: 0.0622 - accuracy: 0.9830 - val_loss: 0.0784 - val_accuracy: 0.9741
# Epoch 36/50
#  - 0s - loss: 0.0594 - accuracy: 0.9830 - val_loss: 0.0845 - val_accuracy: 0.9741
# Epoch 37/50
#  - 0s - loss: 0.0632 - accuracy: 0.9830 - val_loss: 0.0568 - val_accuracy: 0.9828
# Epoch 38/50
#  - 0s - loss: 0.0591 - accuracy: 0.9830 - val_loss: 0.0818 - val_accuracy: 0.9741
# Epoch 39/50
#  - 0s - loss: 0.0541 - accuracy: 0.9872 - val_loss: 0.0669 - val_accuracy: 0.9741
# Epoch 40/50
#  - 0s - loss: 0.0540 - accuracy: 0.9830 - val_loss: 0.0696 - val_accuracy: 0.9741
# Epoch 41/50
#  - 0s - loss: 0.0519 - accuracy: 0.9872 - val_loss: 0.0638 - val_accuracy: 0.9828
# Epoch 42/50
#  - 0s - loss: 0.0510 - accuracy: 0.9872 - val_loss: 0.0719 - val_accuracy: 0.9741
# Epoch 43/50
#  - 0s - loss: 0.0515 - accuracy: 0.9830 - val_loss: 0.0706 - val_accuracy: 0.9741
# Epoch 44/50
#  - 0s - loss: 0.0505 - accuracy: 0.9830 - val_loss: 0.0732 - val_accuracy: 0.9741
# Epoch 45/50
#  - 0s - loss: 0.0577 - accuracy: 0.9830 - val_loss: 0.0539 - val_accuracy: 0.9828
# Epoch 46/50
#  - 0s - loss: 0.0540 - accuracy: 0.9872 - val_loss: 0.0703 - val_accuracy: 0.9741
# Epoch 47/50
#  - 0s - loss: 0.0483 - accuracy: 0.9915 - val_loss: 0.0611 - val_accuracy: 0.9828
# Epoch 48/50
#  - 0s - loss: 0.0474 - accuracy: 0.9872 - val_loss: 0.0671 - val_accuracy: 0.9741
# Epoch 49/50
#  - 0s - loss: 0.0461 - accuracy: 0.9872 - val_loss: 0.0667 - val_accuracy: 0.9741
# Epoch 50/50
#  - 0s - loss: 0.0459 - accuracy: 0.9872 - val_loss: 0.0688 - val_accuracy: 0.9741
