# %%
# Drop-Based Learning Rate Decay
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
from sklearn.preprocessing import LabelEncoder
from keras.callbacks import LearningRateScheduler
# Out:
# Using TensorFlow backend.

# %%
# learning rate schedule
def step_decay(epoch):
	initial_lrate = 0.1
	drop = 0.5
	epochs_drop = 10.0
	lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
	return lrate

# %%
# load dataset
filename='https://gist.githubusercontent.com/nicolomarana/cd4fb1594124f42337157eec1d8cfa64/raw/e9c0b0fba99bb232250d1ecbcd80d1c1f31f50cf/ionosphere'
dataframe = read_csv(filename, header=None)
dataset = dataframe.values

# %%
# split into input (X) and output (Y) variables
X = dataset[:,0:34].astype(float)
Y = dataset[:,34]

# %%
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(Y)
Y = encoder.transform(Y)

# %%
# create model
model = Sequential()
model.add(Dense(34, input_dim=34, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile model
sgd = SGD(lr=0.0, momentum=0.9)
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
# learning schedule callback
lrate = LearningRateScheduler(step_decay)
callbacks_list = [lrate]

# %%
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=50, batch_size=28, callbacks=callbacks_list, verbose=2)
# Out:
# Train on 235 samples, validate on 116 samples
# Epoch 1/50
#  - 0s - loss: 0.6138 - accuracy: 0.6809 - val_loss: 0.4461 - val_accuracy: 0.8966
# Epoch 2/50
#  - 0s - loss: 0.4164 - accuracy: 0.8638 - val_loss: 0.2963 - val_accuracy: 0.9397
# Epoch 3/50
#  - 0s - loss: 0.2684 - accuracy: 0.9106 - val_loss: 0.2090 - val_accuracy: 0.9741
# Epoch 4/50
#  - 0s - loss: 0.1867 - accuracy: 0.9234 - val_loss: 0.1807 - val_accuracy: 0.9569
# Epoch 5/50
#  - 0s - loss: 0.1543 - accuracy: 0.9447 - val_loss: 0.1516 - val_accuracy: 0.9569
# Epoch 6/50
#  - 0s - loss: 0.1458 - accuracy: 0.9532 - val_loss: 0.1334 - val_accuracy: 0.9655
# Epoch 7/50
#  - 0s - loss: 0.1108 - accuracy: 0.9702 - val_loss: 0.0915 - val_accuracy: 0.9914
# Epoch 8/50
#  - 0s - loss: 0.1095 - accuracy: 0.9702 - val_loss: 0.1815 - val_accuracy: 0.9569
# Epoch 9/50
#  - 0s - loss: 0.1113 - accuracy: 0.9702 - val_loss: 0.0805 - val_accuracy: 0.9914
# Epoch 10/50
#  - 0s - loss: 0.1453 - accuracy: 0.9574 - val_loss: 0.0749 - val_accuracy: 0.9914
# Epoch 11/50
#  - 0s - loss: 0.1073 - accuracy: 0.9532 - val_loss: 0.0690 - val_accuracy: 0.9914
# Epoch 12/50
#  - 0s - loss: 0.0932 - accuracy: 0.9787 - val_loss: 0.1204 - val_accuracy: 0.9828
# Epoch 13/50
#  - 0s - loss: 0.0721 - accuracy: 0.9830 - val_loss: 0.0727 - val_accuracy: 0.9914
# Epoch 14/50
#  - 0s - loss: 0.0699 - accuracy: 0.9830 - val_loss: 0.0714 - val_accuracy: 0.9914
# Epoch 15/50
#  - 0s - loss: 0.0665 - accuracy: 0.9872 - val_loss: 0.0763 - val_accuracy: 0.9914
# Epoch 16/50
#  - 0s - loss: 0.0591 - accuracy: 0.9872 - val_loss: 0.0700 - val_accuracy: 0.9914
# Epoch 17/50
#  - 0s - loss: 0.0610 - accuracy: 0.9872 - val_loss: 0.0751 - val_accuracy: 0.9914
# Epoch 18/50
#  - 0s - loss: 0.0556 - accuracy: 0.9872 - val_loss: 0.0640 - val_accuracy: 0.9914
# Epoch 19/50
#  - 0s - loss: 0.0547 - accuracy: 0.9872 - val_loss: 0.0676 - val_accuracy: 0.9914
# Epoch 20/50
#  - 0s - loss: 0.0510 - accuracy: 0.9872 - val_loss: 0.0614 - val_accuracy: 0.9914
# Epoch 21/50
#  - 0s - loss: 0.0508 - accuracy: 0.9872 - val_loss: 0.0648 - val_accuracy: 0.9914
# Epoch 22/50
#  - 0s - loss: 0.0493 - accuracy: 0.9872 - val_loss: 0.0729 - val_accuracy: 0.9914
# Epoch 23/50
#  - 0s - loss: 0.0486 - accuracy: 0.9872 - val_loss: 0.0661 - val_accuracy: 0.9914
# Epoch 24/50
#  - 0s - loss: 0.0472 - accuracy: 0.9872 - val_loss: 0.0624 - val_accuracy: 0.9914
# Epoch 25/50
#  - 0s - loss: 0.0465 - accuracy: 0.9872 - val_loss: 0.0618 - val_accuracy: 0.9914
# Epoch 26/50
#  - 0s - loss: 0.0465 - accuracy: 0.9872 - val_loss: 0.0649 - val_accuracy: 0.9914
# Epoch 27/50
#  - 0s - loss: 0.0454 - accuracy: 0.9872 - val_loss: 0.0640 - val_accuracy: 0.9914
# Epoch 28/50
#  - 0s - loss: 0.0448 - accuracy: 0.9872 - val_loss: 0.0641 - val_accuracy: 0.9914
# Epoch 29/50
#  - 0s - loss: 0.0440 - accuracy: 0.9872 - val_loss: 0.0608 - val_accuracy: 0.9914
# Epoch 30/50
#  - 0s - loss: 0.0437 - accuracy: 0.9872 - val_loss: 0.0598 - val_accuracy: 0.9914
# Epoch 31/50
#  - 0s - loss: 0.0436 - accuracy: 0.9872 - val_loss: 0.0605 - val_accuracy: 0.9914
# Epoch 32/50
#  - 0s - loss: 0.0427 - accuracy: 0.9872 - val_loss: 0.0624 - val_accuracy: 0.9914
# Epoch 33/50
#  - 0s - loss: 0.0424 - accuracy: 0.9872 - val_loss: 0.0681 - val_accuracy: 0.9914
# Epoch 34/50
#  - 0s - loss: 0.0427 - accuracy: 0.9872 - val_loss: 0.0664 - val_accuracy: 0.9914
# Epoch 35/50
#  - 0s - loss: 0.0421 - accuracy: 0.9872 - val_loss: 0.0625 - val_accuracy: 0.9914
# Epoch 36/50
#  - 0s - loss: 0.0416 - accuracy: 0.9872 - val_loss: 0.0619 - val_accuracy: 0.9914
# Epoch 37/50
#  - 0s - loss: 0.0417 - accuracy: 0.9872 - val_loss: 0.0606 - val_accuracy: 0.9914
# Epoch 38/50
#  - 0s - loss: 0.0416 - accuracy: 0.9872 - val_loss: 0.0604 - val_accuracy: 0.9914
# Epoch 39/50
#  - 0s - loss: 0.0406 - accuracy: 0.9872 - val_loss: 0.0663 - val_accuracy: 0.9914
# Epoch 40/50
#  - 0s - loss: 0.0417 - accuracy: 0.9872 - val_loss: 0.0719 - val_accuracy: 0.9914
# Epoch 41/50
#  - 0s - loss: 0.0415 - accuracy: 0.9872 - val_loss: 0.0683 - val_accuracy: 0.9914
# Epoch 42/50
#  - 0s - loss: 0.0409 - accuracy: 0.9872 - val_loss: 0.0629 - val_accuracy: 0.9914
# Epoch 43/50
#  - 0s - loss: 0.0402 - accuracy: 0.9915 - val_loss: 0.0617 - val_accuracy: 0.9914
# Epoch 44/50
#  - 0s - loss: 0.0401 - accuracy: 0.9915 - val_loss: 0.0605 - val_accuracy: 0.9914
# Epoch 45/50
#  - 0s - loss: 0.0401 - accuracy: 0.9915 - val_loss: 0.0606 - val_accuracy: 0.9914
# Epoch 46/50
#  - 0s - loss: 0.0401 - accuracy: 0.9915 - val_loss: 0.0611 - val_accuracy: 0.9914
# Epoch 47/50
#  - 0s - loss: 0.0398 - accuracy: 0.9915 - val_loss: 0.0607 - val_accuracy: 0.9914
# Epoch 48/50
#  - 0s - loss: 0.0397 - accuracy: 0.9915 - val_loss: 0.0615 - val_accuracy: 0.9914
# Epoch 49/50
#  - 0s - loss: 0.0397 - accuracy: 0.9915 - val_loss: 0.0608 - val_accuracy: 0.9914
# Epoch 50/50
#  - 0s - loss: 0.0394 - accuracy: 0.9915 - val_loss: 0.0616 - val_accuracy: 0.9914
