# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
import numpy
import pandas

# %%
# Function to create model, required for KerasClassifier
def create_model():
  # create model
  model = Sequential()
  model.add(Dense(12, input_dim=8, activation="relu", kernel_initializer="uniform"))
  model.add(Dense(8, activation="relu", kernel_initializer="uniform"))
  model.add(Dense(1, activation="sigmoid", kernel_initializer="uniform"))
  # Compile model
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# %%
# load pima indians dataset
filename='https://gist.githubusercontent.com/nicolomarana/728b2063e19ff4c6d56790a041693767/raw/f450082c7e2917545fda1a5bda10c4faad647ade/diabetes'
dataset = numpy.loadtxt(filename, delimiter=',', skiprows=1)

# %%
# Dividiamo in input(X) e output(Y)
X = dataset[:,0:8]
Y = dataset[:, 8]

# %%
# create model
model = KerasClassifier(build_fn=create_model, nb_epoch=150, batch_size=10)

# %%
# evaluate using 10-fold cross validation
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
kfold.get_n_splits(X,Y)
results = cross_val_score(model, X, Y, cv=kfold)
print(results.mean())
# Out:
# Epoch 1/1
# 691/691 [==============================] - 0s 348us/step - loss: 0.6805 - accuracy: 0.6469
# 77/77 [==============================] - 0s 432us/step
# Epoch 1/1
# 691/691 [==============================] - 0s 363us/step - loss: 0.6881 - accuracy: 0.6310
# 77/77 [==============================] - 0s 381us/step
# Epoch 1/1
# 691/691 [==============================] - 0s 401us/step - loss: 0.6852 - accuracy: 0.6194
# 77/77 [==============================] - 0s 415us/step
# Epoch 1/1
# 691/691 [==============================] - 0s 365us/step - loss: 0.6898 - accuracy: 0.6425
# 77/77 [==============================] - 0s 378us/step
# Epoch 1/1
# 691/691 [==============================] - 0s 324us/step - loss: 0.6867 - accuracy: 0.6411
# 77/77 [==============================] - 0s 372us/step
# Epoch 1/1
# 691/691 [==============================] - 0s 346us/step - loss: 0.6832 - accuracy: 0.6368
# 77/77 [==============================] - 0s 357us/step
# Epoch 1/1
# 691/691 [==============================] - 0s 399us/step - loss: 0.6783 - accuracy: 0.6397
# 77/77 [==============================] - 0s 583us/step
# Epoch 1/1
# 691/691 [==============================] - 0s 409us/step - loss: 0.6863 - accuracy: 0.6252
# 77/77 [==============================] - 0s 462us/step
# Epoch 1/1
# 692/692 [==============================] - 0s 373us/step - loss: 0.6803 - accuracy: 0.6243
# 76/76 [==============================] - 0s 352us/step
# Epoch 1/1
# 692/692 [==============================] - 0s 397us/step - loss: 0.6901 - accuracy: 0.6257
# 76/76 [==============================] - 0s 415us/step
# 0.6510594606399536
